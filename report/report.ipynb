# %% [markdown]
# # SI140A.01 Probability Theory Course Project Report

# %% [markdown]
# ## 1. Project Background

# %% [markdown]
# ## 2. Abstract

# %% [markdown]
# ## 3. Introduction

# %% [markdown]
# ### 3.1 Team Division of Labor

# %% [markdown]
# ### 3.2 Data Collection

# %% [markdown]
# #### 3.2.1 5 RMB for 3 People and 50 RMB for 10 People

# %% [markdown]
# ## 4. Data Visualization

# %% [markdown]
# ### 4.1 Visualization and Analysis of Collected Data

# %% [markdown]
# ### 4.2 Visualization and Analysis of Simulated Data Compared with Existing Data

# %% [markdown]
# ## 5. Distribution Modeling, Fitting and Testing

# %% [markdown]
# ### 5.1 "Incorrect Models" (Uniform Distribution, Normal Distribution, etc.) + Double Expectation Distribution as the "Correct Distribution"

# %% [markdown]
# ### 5.2 Discussion on Advantages and Disadvantages of Tests

# %% [markdown]
# ## 6. Generative Modeling

# %% [markdown]
# ## 7. Red Packet Snatching Strategies and Recommendations

# %% [markdown]
# ## 8. Further Exploration

# %% [markdown]
# ### 8.1 Holiday Differences

# %% [markdown]
# ### 8.2 Strategy Formulation for Red Packet Groups with Different Users
