# %% [markdown]
# # SI140A.01 概率论课程项目报告

# %% [markdown]
# ## 1. 项目背景

# %% [markdown]
# ## 2. 摘要

# %% [markdown]
# ## 3. 引言

# %% [markdown]
# ### 3.1 团队分工

# %% [markdown]
# ### 3.2 数据收集

# %% [markdown]
# #### 3.2.1 5 RMB 3 人 以及 50RMB 10 人

# %% [markdown]
# ## 4. 数据的可视化

# %% [markdown]
# ### 4.1 已收集数据的可视化与分析

# %% [markdown]
# ### 4.2 模拟生成数据的可视化与分析比较已有数据

# %% [markdown]
# ## 5. 分布建模拟合及检验

# %% [markdown]
# ### 5.1 均匀分布、正态分布等等"错误模型" + 双期望分布即"正确分布"

# %% [markdown]
# ### 5.2 讨论检验的优点和缺点

# %% [markdown]
# ## 6. 生成式建模

# %% [markdown]
# ## 7. 抢红包策略及建议

# %% [markdown]
# ## 8. 进一步探索

# %% [markdown]
# ### 8.1 节假日差异

# %% [markdown]
# ### 8.2 针对不同用户的红包群组的策略制定
